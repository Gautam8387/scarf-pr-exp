# %%
import pandas as pd
import os
import numpy as np
import pickle as pkl

import matplotlib.pyplot as plt

# %%
results = os.listdir('../results')
results = ['../results/'+x+'/results.pkl' for x in results]
results
# Out:
# ['../results/2024.5.2/results.pkl',
#  '../results/2024.6.1/results.pkl',
#  '../results/2024.3.1/results.pkl',
#  '../results/2024.7.1/results.pkl',
#  '../results/2024.11.2/results.pkl',
#  '../results/2024.8.2/results.pkl',
#  '../results/2024.8.0/results.pkl',
#  '../results/2024.5.0/results.pkl',
#  '../results/2024.4.1/results.pkl',
#  '../results/2024.8.1/results.pkl',
#  '../results/2024.11.1/results.pkl',
#  '../results/2024.3.0/results.pkl',
#  '../results/2024.6.2/results.pkl',
#  '../results/2024.2.0/results.pkl',
#  '../results/2024.12.0/results.pkl',
#  '../results/2024.9.0/results.pkl',
#  '../results/2024.10.0/results.pkl',
#  '../results/2024.9.1/results.pkl',
#  '../results/2024.4.0/results.pkl',
#  '../results/2024.2.1/results.pkl',
#  '../results/2024.4.2/results.pkl',
#  '../results/2024.1.1/results.pkl',
#  '../results/2024.6.0/results.pkl',
#  '../results/2024.1.0/results.pkl',
#  '../results/2024.5.1/results.pkl',
#  '../results/2024.7.0/results.pkl']

# %%
dask_versions = []
ram_sizes = []
ram_cols = ['baron_8K_pancreas_rnaseq.zarr', 'hca_783K_blood_rnaseq.zarr', 'saunders_110K_brain_rnaseq.zarr', 'tenx_1.3M_brain_rnaseq.zarr', 'zheng_69K_pbmc_rnaseq.zarr']
for result in results:
    with open(result, 'rb') as f:
        res = pkl.load(f)
    dask_versions.append(res['das_version'])
    ram_sizes.append([np.max(res[x]['ram']) for x in ram_cols])

# %%
df = {'dask_version': dask_versions}
for i, col in enumerate(ram_cols):
    df[col] = [x[i] for x in ram_sizes]
df = pd.DataFrame(df)
df
# Out:
#    dask_version  baron_8K_pancreas_rnaseq.zarr  hca_783K_blood_rnaseq.zarr  \
# 0      2024.5.2                     316.585938                  676.792969
# 1      2024.6.1                     265.265625                  695.750000
# 2      2024.3.1                     271.250000                  665.824219
# 3      2024.7.1                     282.925781                  661.519531
# 4     2024.11.2                     355.585938                11857.617188
# 5      2024.8.2                     369.113281                11830.074219
# 6      2024.8.0                     391.789062                 9605.253906
# 7      2024.5.0                     255.738281                  674.628906
# 8      2024.4.1                     268.457031                  693.132812
# 9      2024.8.1                     404.417969                12292.554688
# 10    2024.11.1                     334.933594                11494.699219
# 11     2024.3.0                     299.781250                  685.765625
# 12     2024.6.2                     271.109375                  681.777344
# 13     2024.2.0                     317.597656                  666.269531
# 14    2024.12.0                     399.453125                11767.593750
# 15     2024.9.0                     455.355469                11318.917969
# 16    2024.10.0                     389.691406                11810.761719
# 17     2024.9.1                     369.246094                11453.675781
# 18     2024.4.0                     322.187500                  696.933594
# 19     2024.2.1                     276.710938                  651.355469
# 20     2024.4.2                     277.066406                  683.250000
# 21     2024.1.1                     250.527344                  677.792969
# 22     2024.6.0                     290.566406                  681.906250
# 23     2024.1.0                     271.558594                  664.796875
# 24     2024.5.1                     302.109375                  692.015625
# 25     2024.7.0                     299.167969                  714.160156
#
#     saunders_110K_brain_rnaseq.zarr  tenx_1.3M_brain_rnaseq.zarr  \
# 0                        622.832031                   767.648438
# 1                        608.535156                   780.566406
# 2                        624.921875                   787.550781
# 3                        590.160156                   721.503906
# 4                       5932.324219                 36206.410156
# 5                       8463.734375                 34108.710938
# 6                       5980.398438                 36086.023438
# 7                        643.906250                   775.136719
# 8                        629.863281                   775.195312
# 9                       5506.449219                 34362.855469
# 10                      5140.140625                 34306.558594
# 11                       604.128906                   773.003906
# 12                       623.414062                   781.386719
# 13                       603.820312                   768.312500
# 14                      5621.160156                 34948.914062
# 15                      6550.246094                 35648.382812
# 16                      5197.070312                 34269.035156
# 17                      5907.320312                 35755.296875
# 18                       641.558594                   763.582031
# 19                       643.464844                   770.601562
# 20                       594.152344                   736.605469
# 21                       628.582031                   760.425781
# 22                       614.898438                   764.562500
# 23                       618.882812                   765.160156
# 24                       628.058594                   728.003906
# 25                       603.867188                   751.472656
#
#     zheng_69K_pbmc_rnaseq.zarr
# 0                   591.558594
# 1                   614.085938
# 2                   639.398438
# 3                   619.132812
# 4                  6208.671875
# 5                  3482.625000
# 6                  3593.652344
# 7                   639.222656
# 8                   619.625000
# 9                  2607.617188
# 10                19618.035156
# 11                  576.003906
# 12                  581.976562
# 13                  655.832031
# 14                 3964.804688
# 15                 3782.148438
# 16                 2683.089844
# 17                 4381.921875
# 18                  625.601562
# 19                  613.566406
# 20                  591.253906
# 21                  563.511719
# 22                  611.359375
# 23                  572.496094
# 24                  568.984375
# 25                  600.929688

# %%
# Zarr: 2.16

# %%
df_sort = df.sort_values(by=['tenx_1.3M_brain_rnaseq.zarr', 'dask_version'])
df_sort
# Out:
#    dask_version  baron_8K_pancreas_rnaseq.zarr  hca_783K_blood_rnaseq.zarr  \
# 3      2024.7.1                     282.925781                  661.519531
# 24     2024.5.1                     302.109375                  692.015625
# 20     2024.4.2                     277.066406                  683.250000
# 25     2024.7.0                     299.167969                  714.160156
# 21     2024.1.1                     250.527344                  677.792969
# 18     2024.4.0                     322.187500                  696.933594
# 22     2024.6.0                     290.566406                  681.906250
# 23     2024.1.0                     271.558594                  664.796875
# 0      2024.5.2                     316.585938                  676.792969
# 13     2024.2.0                     317.597656                  666.269531
# 19     2024.2.1                     276.710938                  651.355469
# 11     2024.3.0                     299.781250                  685.765625
# 7      2024.5.0                     255.738281                  674.628906
# 8      2024.4.1                     268.457031                  693.132812
# 1      2024.6.1                     265.265625                  695.750000
# 12     2024.6.2                     271.109375                  681.777344
# 2      2024.3.1                     271.250000                  665.824219
# 5      2024.8.2                     369.113281                11830.074219
# 16    2024.10.0                     389.691406                11810.761719
# 10    2024.11.1                     334.933594                11494.699219
# 9      2024.8.1                     404.417969                12292.554688
# 14    2024.12.0                     399.453125                11767.593750
# 15     2024.9.0                     455.355469                11318.917969
# 17     2024.9.1                     369.246094                11453.675781
# 6      2024.8.0                     391.789062                 9605.253906
# 4     2024.11.2                     355.585938                11857.617188
#
#     saunders_110K_brain_rnaseq.zarr  tenx_1.3M_brain_rnaseq.zarr  \
# 3                        590.160156                   721.503906
# 24                       628.058594                   728.003906
# 20                       594.152344                   736.605469
# 25                       603.867188                   751.472656
# 21                       628.582031                   760.425781
# 18                       641.558594                   763.582031
# 22                       614.898438                   764.562500
# 23                       618.882812                   765.160156
# 0                        622.832031                   767.648438
# 13                       603.820312                   768.312500
# 19                       643.464844                   770.601562
# 11                       604.128906                   773.003906
# 7                        643.906250                   775.136719
# 8                        629.863281                   775.195312
# 1                        608.535156                   780.566406
# 12                       623.414062                   781.386719
# 2                        624.921875                   787.550781
# 5                       8463.734375                 34108.710938
# 16                      5197.070312                 34269.035156
# 10                      5140.140625                 34306.558594
# 9                       5506.449219                 34362.855469
# 14                      5621.160156                 34948.914062
# 15                      6550.246094                 35648.382812
# 17                      5907.320312                 35755.296875
# 6                       5980.398438                 36086.023438
# 4                       5932.324219                 36206.410156
#
#     zheng_69K_pbmc_rnaseq.zarr
# 3                   619.132812
# 24                  568.984375
# 20                  591.253906
# 25                  600.929688
# 21                  563.511719
# 18                  625.601562
# 22                  611.359375
# 23                  572.496094
# 0                   591.558594
# 13                  655.832031
# 19                  613.566406
# 11                  576.003906
# 7                   639.222656
# 8                   619.625000
# 1                   614.085938
# 12                  581.976562
# 2                   639.398438
# 5                  3482.625000
# 16                 2683.089844
# 10                19618.035156
# 9                  2607.617188
# 14                 3964.804688
# 15                 3782.148438
# 17                 4381.921875
# 6                  3593.652344
# 4                  6208.671875

# %%
df_sort[df_sort['tenx_1.3M_brain_rnaseq.zarr']<800].sort_values(by='dask_version')
# Out:
#    dask_version  baron_8K_pancreas_rnaseq.zarr  hca_783K_blood_rnaseq.zarr  \
# 23     2024.1.0                     271.558594                  664.796875
# 21     2024.1.1                     250.527344                  677.792969
# 13     2024.2.0                     317.597656                  666.269531
# 19     2024.2.1                     276.710938                  651.355469
# 11     2024.3.0                     299.781250                  685.765625
# 2      2024.3.1                     271.250000                  665.824219
# 18     2024.4.0                     322.187500                  696.933594
# 8      2024.4.1                     268.457031                  693.132812
# 20     2024.4.2                     277.066406                  683.250000
# 7      2024.5.0                     255.738281                  674.628906
# 24     2024.5.1                     302.109375                  692.015625
# 0      2024.5.2                     316.585938                  676.792969
# 22     2024.6.0                     290.566406                  681.906250
# 1      2024.6.1                     265.265625                  695.750000
# 12     2024.6.2                     271.109375                  681.777344
# 25     2024.7.0                     299.167969                  714.160156
# 3      2024.7.1                     282.925781                  661.519531
#
#     saunders_110K_brain_rnaseq.zarr  tenx_1.3M_brain_rnaseq.zarr  \
# 23                       618.882812                   765.160156
# 21                       628.582031                   760.425781
# 13                       603.820312                   768.312500
# 19                       643.464844                   770.601562
# 11                       604.128906                   773.003906
# 2                        624.921875                   787.550781
# 18                       641.558594                   763.582031
# 8                        629.863281                   775.195312
# 20                       594.152344                   736.605469
# 7                        643.906250                   775.136719
# 24                       628.058594                   728.003906
# 0                        622.832031                   767.648438
# 22                       614.898438                   764.562500
# 1                        608.535156                   780.566406
# 12                       623.414062                   781.386719
# 25                       603.867188                   751.472656
# 3                        590.160156                   721.503906
#
#     zheng_69K_pbmc_rnaseq.zarr
# 23                  572.496094
# 21                  563.511719
# 13                  655.832031
# 19                  613.566406
# 11                  576.003906
# 2                   639.398438
# 18                  625.601562
# 8                   619.625000
# 20                  591.253906
# 7                   639.222656
# 24                  568.984375
# 0                   591.558594
# 22                  611.359375
# 1                   614.085938
# 12                  581.976562
# 25                  600.929688
# 3                   619.132812

# %%
df_sort.to_csv('../results/results.csv', index=False)

# %% [markdown]
# # Plots

# %%
for result in results:
    with open(result, 'rb') as f:
        res = pkl.load(f)
    print(res['das_version'])
    os.makedirs('../plots/'+res['das_version'], exist_ok=True)
    for col in ram_cols:
        print(col)
        plt.plot(res[col]['ram'])
        plt.title(col)
        plt.xlabel('Time (s)')
        plt.ylabel('RAM (MB)')
        plt.savefig('../plots/'+res['das_version']+'/'+col+'.png')
        plt.close()
    print()
    print()
# Out:
# 2024.9.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.8.2
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.5.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.1.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.2.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.1.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.9.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.7.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.7.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.8.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.5.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.6.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.4.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.10.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.11.2
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.6.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.12.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.4.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.3.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.2.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.5.2
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.4.2
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.8.0
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.3.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.6.2
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
#
#
# 2024.11.1
# baron_8K_pancreas_rnaseq.zarr
# hca_783K_blood_rnaseq.zarr
# saunders_110K_brain_rnaseq.zarr
# tenx_1.3M_brain_rnaseq.zarr
# zheng_69K_pbmc_rnaseq.zarr
