# %%
import psutil
import time
import threading
import matplotlib.pyplot as plt
import os
import sys
import numpy as np
sys.path.append('..')

# %%
from utils.monitor_ram import monitor_ram
from utils.monitor_cpu import monitor_cpu

# %%
from scarf import scarf

# %%
scarf.fetch_dataset(
    dataset_name='baron_8K_pancreas_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrDirReader('../data/baron_8K_pancreas_rnaseq', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/baron_8K_pancreas_rnaseq.zarr')
writer.dump()
# Out:
# WARNING: feature_types extraction failed from features.tsv.gz in column 2
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %%
scarf.fetch_dataset(
    dataset_name='kang_14K_ifnb-pbmc_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrDirReader('../data/kang_14K_ifnb-pbmc_rnaseq', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/kang_14K_ifnb-pbmc_rnaseq.zarr')
writer.dump()
# Out:
# WARNING: feature_types extraction failed from features.tsv.gz in column 2
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %%
scarf.fetch_dataset(
    dataset_name='kang_15K_pbmc_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrDirReader('../data/kang_15K_pbmc_rnaseq', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/kang_15K_pbmc_rnaseq.zarr')
writer.dump()
# Out:
# WARNING: feature_types extraction failed from features.tsv.gz in column 2
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %%
scarf.fetch_dataset(
    dataset_name='zheng_69K_pbmc_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrDirReader('../data/zheng_69K_pbmc_rnaseq', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/zheng_69K_pbmc_rnaseq.zarr')
writer.dump()
# Out:
# WARNING: feature_types extraction failed from features.tsv.gz in column 2
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %%
scarf.fetch_dataset(
    dataset_name='hca_783K_blood_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrDirReader('../data/hca_783K_blood_rnaseq', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/hca_783K_blood_rnaseq.zarr')
writer.dump()
# Out:
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %%
scarf.fetch_dataset(
    dataset_name='tenx_1.3M_brain_rnaseq', 
    save_path='../data/',
)

# %%
reader = scarf.CrH5Reader('../data/tenx_1.3M_brain_rnaseq/data.h5', is_filtered=False)
writer = scarf.CrToZarr(reader, '../data/tenx_1.3M_brain_rnaseq.zarr')
writer.dump()
# Out:
# Filtering out background barcodes:   0%|                                                                      …
#   0%|                                                                                                         …

# %% [markdown]
# # DataStores

# %%
ds_8k = scarf.DataStore('../data/baron_8K_pancreas_rnaseq.zarr')
ds_8k.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 85. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# (RNA) Computing normed_tot:   0%|                                                                             …
# ...

# %%
ds_14k = scarf.DataStore('../data/kang_14K_ifnb-pbmc_rnaseq.zarr')
ds_14k.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# WARNING: Minimum cell count (604) is lower than size factor multiplier (1000)
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 144. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# ...

# %%
ds_15k = scarf.DataStore('../data/kang_15K_pbmc_rnaseq.zarr')
ds_15k.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# WARNING: Minimum cell count (562) is lower than size factor multiplier (1000)
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 146. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# ...

# %%
ds_69k = scarf.DataStore('../data/zheng_69K_pbmc_rnaseq.zarr')
ds_69k.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# WARNING: Minimum cell count (501) is lower than size factor multiplier (1000)
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 674. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# ...

# %%
ds_783k = scarf.DataStore('../data/hca_783K_blood_rnaseq.zarr')
ds_783k.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# WARNING: Minimum cell count (501) is lower than size factor multiplier (1000)
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 6486. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# ...

# %%
ds_1_3m = scarf.DataStore('../data/tenx_1.3M_brain_rnaseq.zarr')
ds_1_3m.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 13061. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# (RNA) Computing normed_tot:   0%|                                                                             …
# ...

# %% [markdown]
# # Merge

# %%
ds_14k = scarf.DataStore('../data/kang_14K_ifnb-pbmc_rnaseq.zarr')
ds_15k = scarf.DataStore('../data/kang_15K_pbmc_rnaseq.zarr')

merged = scarf.DatasetMerge(
    datasets=[ds_14k, ds_15k],
    zarr_path='../data/kang_merged_14k_15k.zarr',
    names=['stim', 'ctrl'],
)

merged.dump()
# Out:
# INFO: Dumping RNA
# Writing data from assay 1/2 to merged file:   0%|                                                             …
# Writing data from assay 2/2 to merged file:   0%|                                                             …
# INFO: Merging complete

# %%
ds_merged = scarf.DataStore('../data/kang_merged_14k_15k.zarr')
ds_merged.mark_hvgs()
# Out:
# (RNA) Computing nCells and dropOuts:   0%|                                                                    …
# (RNA) Computing nCounts:   0%|                                                                                …
# WARNING: Minimum cell count (562) is lower than size factor multiplier (1000)
# (RNA) Computing nFeatures:   0%|                                                                              …
# (RNA) Computing RNA_percentMito:   0%|                                                                        …
# (RNA) Computing RNA_percentRibo:   0%|                                                                        …
# INFO: Setting `min_cells` to 290. Only those genes that are present in atleast this number of cells will be considered HVGs.
# INFO: Calculating summary statistics
# (RNA) Computing nCells:   0%|                                                                                 …
# ...

# %% [markdown]
# # Filter

# %%
ds_8k.auto_filter_cells()
ds_14k.auto_filter_cells()
ds_15k.auto_filter_cells()
ds_69k.auto_filter_cells()
ds_783k.auto_filter_cells()
ds_1_3m.auto_filter_cells()
ds_merged.auto_filter_cells()
# Out:
# INFO: 379 cells flagged for filtering out using attribute RNA_nCounts
# INFO: 191 cells flagged for filtering out using attribute RNA_nFeatures
# INFO: 154 cells flagged for filtering out using attribute RNA_percentMito
# INFO: 302 cells flagged for filtering out using attribute RNA_percentRibo
# INFO: 823 cells flagged for filtering out using attribute RNA_nCounts
# INFO: 680 cells flagged for filtering out using attribute RNA_nFeatures
# INFO: 450 cells flagged for filtering out using attribute RNA_percentMito
# INFO: 7 cells flagged for filtering out using attribute RNA_percentRibo
# INFO: 829 cells flagged for filtering out using attribute RNA_nCounts
# INFO: 718 cells flagged for filtering out using attribute RNA_nFeatures
# INFO: 432 cells flagged for filtering out using attribute RNA_percentMito
# INFO: 1 cells flagged for filtering out using attribute RNA_percentRibo
# INFO: 2349 cells flagged for filtering out using attribute RNA_nCounts
# ...

# %% [markdown]
# # UMAP

# %%
ds_8k.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_8k.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_8k.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_14k.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_14k.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_14k.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_15k.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_15k.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_15k.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_69k.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_69k.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_69k.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_783k.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_783k.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_783k.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_1_3m.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_1_3m.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_1_3m.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %%
ds_merged.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
)
ds_merged.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds_merged.run_leiden_clustering(
    resolution=0.5
)
# Out:
# Normalizing with feature subset:   0%|                                                                        …
# Writing data to normed__I__hvgs/data:   0%|                                                                   …
# Calculating mean of norm. data:   0%|                                                                         …
# Calculating std. dev. of norm. data:   0%|                                                                    …
# Fitting PCA:   0%|                                                                                            …
# Fitting ANN:   0%|                                                                                            …
# Fitting kmeans:   0%|                                                                                         …
# Estimating seed partitions:   0%|                                                                             …
# ...

# %% [markdown]
# # Plots

# %%
ds_8k.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_14k.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_15k.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_69k.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_783k.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_1_3m.plot_layout(
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
ds_merged.cells.head()
# Out:
#       I                     ids             names  RNA_UMAP1  RNA_UMAP2  \
# 0  True  stim__GACACTGAAAAACG-1  GACACTGAAAAACG-1  -3.031583  10.614032
# 1  True  stim__GAAAGATGTTTCAC-1  GAAAGATGTTTCAC-1  22.131290  10.029479
# 2  True  stim__CTCAGGCTAGCCTA-1  CTCAGGCTAGCCTA-1  -4.602677 -14.787618
# 3  True  stim__CTGAACGATTCCCG-1  CTGAACGATTCCCG-1  -0.335594 -30.666565
# 4  True  stim__CTATCCCTACGACT-1  CTATCCCTACGACT-1  -3.504239  29.048988
#
#    RNA_leiden_cluster  RNA_nCounts  RNA_nFeatures  RNA_percentMito  \
# 0                   6        736.0          427.0         0.271739
# 1                   4       2840.0          905.0         0.070423
# 2                   2       1906.0          701.0         0.367261
# 3                   7       1920.0          850.0         0.104167
# 4                   6        994.0          464.0         0.100604
#
#    RNA_percentRibo  orig_RNA_nCounts  orig_RNA_nFeatures  \
# 0        25.679348             736.0               427.0
# ...

# %%
ds_merged.cells.insert(
    column_name='sample_id',
    values=[x.split('__')[0] for x in ds_merged.cells.fetch_all('ids')],
    overwrite=True
)

# %%
ds_merged.cells.head()
# Out:
#       I                     ids             names  RNA_UMAP1  RNA_UMAP2  \
# 0  True  stim__GACACTGAAAAACG-1  GACACTGAAAAACG-1  -3.031583  10.614032
# 1  True  stim__GAAAGATGTTTCAC-1  GAAAGATGTTTCAC-1  22.131290  10.029479
# 2  True  stim__CTCAGGCTAGCCTA-1  CTCAGGCTAGCCTA-1  -4.602677 -14.787618
# 3  True  stim__CTGAACGATTCCCG-1  CTGAACGATTCCCG-1  -0.335594 -30.666565
# 4  True  stim__CTATCCCTACGACT-1  CTATCCCTACGACT-1  -3.504239  29.048988
#
#    RNA_leiden_cluster  RNA_nCounts  RNA_nFeatures  RNA_percentMito  \
# 0                   6        736.0          427.0         0.271739
# 1                   4       2840.0          905.0         0.070423
# 2                   2       1906.0          701.0         0.367261
# 3                   7       1920.0          850.0         0.104167
# 4                   6        994.0          464.0         0.100604
#
#    RNA_percentRibo  orig_RNA_nCounts  orig_RNA_nFeatures  \
# 0        25.679348             736.0               427.0
# ...

# %%
ds_merged.plot_layout(
    layout_key='RNA_UMAP',
    color_by='sample_id'
)
# Out:
# /media/chs.gpu/nygen/scarf-metrics/benchmark/../scarf/scarf/plots.py:597: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centers = df[[x, y, vc]].groupby(vc).median().T

# %%
# %load_ext autotime
